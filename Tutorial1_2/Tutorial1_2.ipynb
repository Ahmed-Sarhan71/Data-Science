# %% [markdown]
# # Add mall customer to google colab

# %%
# !wget https://raw.githubusercontent.com/Ahmed-Sarhan71/Data-Science/main/EDA1/Advertising.csv

# %%
import pandas as pd
import seaborn as sns

df=pd.read_csv('mall_customer.csv')

# %%
df.shape
# Out:
# (200, 5)

# %%
df.head()
# Out:
#    CustomerID   Genre  Age  Annual_Income_(k$)  Spending_Score
# 0           1    Male   19                  15              39
# 1           2    Male   21                  15              81
# 2           3  Female   20                  16               6
# 3           4  Female   23                  16              77
# 4           5  Female   31                  17              40

# %%
#descriptive question

df.mean()

# What is the mean of the Age?
# What is the average spending score?
# What is the percentage of female among the customer
# What is the average age of the customer
# Out:
# <ipython-input-5-58ae6ca07173>:3: FutureWarning: The default value of numeric_only in DataFrame.mean is deprecated. In a future version, it will default to False. In addition, specifying 'numeric_only=None' is deprecated. Select only valid columns or specify the value of numeric_only to silence this warning.
#   df.mean()
# CustomerID            100.50
# Age                    38.85
# Annual_Income_(k$)     60.56
# Spending_Score         50.20
# dtype: float64

# %%
pip install sweetviz
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 15.1/15.1 MB 56.6 MB/s eta 0:00:00
# ...

# %%
#sweetviz library

import sweetviz as sv

#analyzing the dataset
advert_report = sv.analyze(df)

advert_report.show_html('mall_customer.html')
# Out:
#                                              |          | [  0%]   00:00 -> (? left)
# Report mall_customer.html was generated! NOTEBOOK/COLAB USERS: the web browser MAY not pop up, regardless, the report IS saved in your notebook/colab files.
